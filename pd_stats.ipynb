# %%
import numpy as np
from scipy.stats import binom
binom.pmf(p=0.5,k=2,n=5)
# Out:
# np.float64(0.31249999999999983)

# %%
binom.pmf(p=0.5,k=0,n=5)
# Out:
# np.float64(0.031249999999999976)

# %%
binom.cdf(p=0.5,k=2,n=5)
# Out:
# np.float64(0.5)

# %%
from numpy import random 
import  matplotlib.pyplot as plt
import seaborn as sns
x = random.binomial(n=10, p=0.5, size=1000)  
sns.histplot(x, kde=True)  
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np
mu, sigma = 0.5, 0.1
s = np.random.normal(mu, sigma, 1000)  # Create the bins and histogram
n,bins, p= plt.hist(s, 20, density=True)  # Plot the distribution curve
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( -(bins - mu)**2 / (2 *  sigma**2) ), linewidth=3, color='y')
plt.show()

# %%
#poisson
from scipy.stats import poisson
mu=3
k=5
poisson.pmf(mu,k)
# Out:
# np.float64(0.1403738958142805)

# %%
poisson.rvs(mu=5,size=100)
# Out:
# array([ 6,  4,  5,  2,  5,  4,  4,  6,  3,  5,  3,  7,  3,  5,  5,  5,  0,
#         4,  5,  1,  7,  3,  2,  6,  4,  5,  3,  3,  3,  3,  8,  4,  2,  9,
#         6,  3,  2,  7,  9, 10,  7,  9,  8, 11,  4,  7,  8,  9,  5,  3,  8,
#         6,  5,  6,  5,  4,  4,  7,  4,  4,  2,  3,  7, 10,  9,  4,  4,  7,
#         6,  4,  2,  6,  7,  2,  7, 11,  5,  9, 10,  3,  5,  5,  2,  6,  4,
#         6,  4,  5,  9,  5,  6,  4,  3,  3,  4,  6,  1,  4,  3,  4])

# %%
from scipy.stats import poisson 
import matplotlib.pyplot as plt
#generate Poisson distribution with sample size 10000  
x = poisson.rvs(mu=3, size=10000)
#create plot of Poisson distribution  
plt.hist(x, density=True, edgecolor='black')
plt.show()

# %%
import numpy as np  
import scipy.stats as stats
data = np.array([6, 7, 7, 12, 13, 13, 15, 16, 19, 22,300])
data=stats.zscore(data)
print(data)
data=data.reshape(-1,1)
print(data)
# Out:
# [-0.40039619 -0.38829631 -0.38829631 -0.32779688 -0.315697   -0.315697
#  -0.29149723 -0.27939734 -0.24309769 -0.20679803  3.15696998]
# [[-0.40039619]
#  [-0.38829631]
#  [-0.38829631]
#  [-0.32779688]
#  [-0.315697  ]
#  [-0.315697  ]
#  [-0.29149723]
#  [-0.27939734]
#  [-0.24309769]
#  [-0.20679803]
#  [ 3.15696998]]

# %%
data.mean()
# Out:
# np.float64(39.09090909090909)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
data_scaled=sc.fit_transform(data)
data_scaled
# Out:
# array([[-0.40039619],
#        [-0.38829631],
#        [-0.38829631],
#        [-0.32779688],
#        [-0.315697  ],
#        [-0.315697  ],
#        [-0.29149723],
#        [-0.27939734],
#        [-0.24309769],
#        [-0.20679803],
#        [ 3.15696998]])

# %%
sa=np.array([[-0.40039619],
       [-0.38829631],
       [-0.38829631],
       [-0.32779688],
       [-0.315697  ],
       [-0.315697  ],
       [-0.29149723],
       [-0.27939734],
       [-0.24309769],
       [-0.20679803],
       [ 3.15696998]])

# %%
sa.mean()
# Out:
# np.float64(4.0371746350005693e-17)

# %%
sa.std()
# Out:
# np.float64(1.0000000008752112)

# %%
import numpy as np  
import scipy.stats as st  
population =np.array( [12, 12, 13, 13, 15, 16, 17, 22, 23, 25, 26, 27, 28, 28, 29])
sample=np.array([12,13,17,25,28])
st.t.interval(confidence=0.95, df=len(sample)-1, loc=np.mean(sample),  scale=st.sem(sample))
# Out:
# (np.float64(10.089384507879313), np.float64(27.910615492120687))

# %%
population =np.array( [12, 12, 13, 13, 15, 16, 17, 22, 23, 25, 26, 27, 28, 28, 29])
population.mean()
# Out:
# np.float64(20.4)

# %%
sample.mean()
# Out:
# np.float64(19.0)
