# %%
import pandas as pd

# %%
d=pd.read_csv(r"C:\Users\Live wire\Downloads\titanic.csv")
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d=pd.read_csv("titanic.csv")
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
d.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
print("hello\nworld")
# Out:
# hello
# world

# %%
d.columns[d.isna().any()]
# Out:
# Index(['Age', 'Cabin', 'Embarked'], dtype='object')

# %%
d['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
d['Embarked']=d['Embarked'].fillna(d['Embarked'].mode()[0])
d.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
d['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
e=pd.get_dummies(d["Embarked"])
e
# Out:
#          C      Q      S
# 0    False  False   True
# 1     True  False  False
# 2    False  False   True
# 3    False  False   True
# 4    False  False   True
# ..     ...    ...    ...
# 886  False  False   True
# 887  False  False   True
# 888  False  False   True
# 889   True  False  False
# 890  False   True  False
#
# [891 rows x 3 columns]

# %%
d.groupby("Sex")["Survived"].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
d.groupby("Pclass")["Survived"].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
d=d.drop(['Cabin', 'Embarked'],axis="columns")
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d["Age"]=d['Age'].fillna(d['Age'].median())
d['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
d.columns[d.isna().any()]
# Out:
# Index([], dtype='object')

# %%
d.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.361582    0.523008
# std     257.353842    0.486592    0.836071   13.019697    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 69.7+ KB

# %%
s=pd.get_dummies(d['Sex'])
d=pd.concat([d,s],axis=1)
d=d.drop("Sex",axis="columns")
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
d.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
# 5                                   Moran, Mr. James  28.0      0      0
# 6                            McCarthy, Mr. Timothy J  54.0      0      0
# ...

# %%
d.tail(15)
# Out:
#      PassengerId  Survived  Pclass  \
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                               Name   Age  SibSp  Parch  \
# 876                  Gustafsson, Mr. Alfred Ossian  20.0      0      0
# 877                           Petroff, Mr. Nedelio  19.0      0      0
# 878                             Laleff, Mr. Kristo  28.0      0      0
# 879  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0      0      1
# ...

# %%
de={"name":["nisha","lisa","bosha","vijay","hussain","pradheepa","gavaskar","thaniyarasu","lokesh","anusha"],
"course":["DS","AI","AI","DS","DS","DS","AI","DA","DS","ML"]}
de
# Out:
# {'name': ['nisha',
#   'lisa',
#   'bosha',
#   'vijay',
#   'hussain',
#   'pradheepa',
#   'gavaskar',
#   'thaniyarasu',
#   'lokesh',
#   'anusha'],
#  'course': ['DS', 'AI', 'AI', 'DS', 'DS', 'DS', 'AI', 'DA', 'DS', 'ML']}

# %%
df=pd.DataFrame(de)
df
# Out:
#           name course
# 0        nisha     DS
# 1         lisa     AI
# 2        bosha     AI
# 3        vijay     DS
# 4      hussain     DS
# 5    pradheepa     DS
# 6     gavaskar     AI
# 7  thaniyarasu     DA
# 8       lokesh     DS
# 9       anusha     ML

# %%
d[(d["PassengerId"]>25) & (d['Fare']>50)]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 34            35         0       1
# 35            36         0       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                  Name   Age  SibSp  Parch  \
# 27                     Fortune, Mr. Charles Alexander  19.0      3      2
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  28.0      1      0
# 34                            Meyer, Mr. Edgar Joseph  28.0      1      0
# 35                     Holverson, Mr. Alexander Oskar  42.0      1      0
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  49.0      1      0
# ..                                                ...   ...    ...    ...
# ...

# %%
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
d.sort_values("Fare")
# Out:
#      PassengerId  Survived  Pclass                                Name   Age  \
# 271          272         1       3        Tornquist, Mr. William Henry  25.0
# 597          598         0       3                 Johnson, Mr. Alfred  49.0
# 302          303         0       3     Johnson, Mr. William Cahoone Jr  19.0
# 633          634         0       1       Parr, Mr. William Henry Marsh  28.0
# 277          278         0       2         Parkes, Mr. Francis "Frank"  28.0
# ..           ...       ...     ...                                 ...   ...
# 438          439         0       1                   Fortune, Mr. Mark  64.0
# 341          342         1       1      Fortune, Miss. Alice Elizabeth  24.0
# 737          738         1       1              Lesurer, Mr. Gustave J  35.0
# 258          259         1       1                    Ward, Miss. Anna  35.0
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez  36.0
#
# ...

# %%
d.sort_values("Fare",ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                Name   Age  \
# 258          259         1       1                    Ward, Miss. Anna  35.0
# 737          738         1       1              Lesurer, Mr. Gustave J  35.0
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez  36.0
# 88            89         1       1          Fortune, Miss. Mabel Helen  23.0
# 27            28         0       1      Fortune, Mr. Charles Alexander  19.0
# ..           ...       ...     ...                                 ...   ...
# 633          634         0       1       Parr, Mr. William Henry Marsh  28.0
# 413          414         0       2      Cunningham, Mr. Alfred Fleming  28.0
# 822          823         0       1     Reuchlin, Jonkheer. John George  38.0
# 732          733         0       2                Knight, Mr. Robert J  28.0
# 674          675         0       2          Watson, Mr. Ennis Hastings  28.0
#
# ...

# %%
d['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
d['Survived'].value_counts(normalize=True)
# Out:
# Survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %%
d[d['female']& d["Survived"]]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name   Age  SibSp  Parch  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0      0      2
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  14.0      1      0
# ..                                                 ...   ...    ...    ...
# ...
