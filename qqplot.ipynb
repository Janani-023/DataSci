# %%
import numpy as np
b=np.random.binomial(n=10,p=0.2,size=100)
b
# Out:
# array([1, 0, 0, 3, 2, 1, 2, 2, 0, 1, 2, 2, 2, 2, 3, 6, 3, 2, 5, 4, 3, 2,
#        4, 2, 0, 2, 1, 4, 3, 1, 0, 4, 1, 2, 0, 2, 1, 4, 4, 3, 1, 3, 3, 2,
#        1, 3, 2, 2, 4, 2, 1, 2, 3, 2, 3, 2, 1, 3, 1, 1, 3, 0, 0, 1, 1, 3,
#        3, 1, 0, 4, 2, 1, 2, 2, 3, 1, 2, 3, 3, 2, 2, 3, 2, 0, 1, 3, 1, 1,
#        2, 3, 5, 2, 3, 1, 1, 3, 1, 2, 1, 0], dtype=int32)

# %%
import statsmodels.api  as sm

# %%
sm.qqplot(b,line='45')
import matplotlib.pyplot as plt
plt.show()

# %%
n=np.random.normal(0,1,100)
sm.qqplot(n,line='45')
plt.show()

# %%
import pandas as pd
t=pd.read_csv("titanic.csv")
t
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
sm.qqplot(t['Age'],line='45')
plt.show()
