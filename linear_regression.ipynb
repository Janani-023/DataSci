# %%
 import pandas as pd

# %%
d=pd.read_csv("Salary_Data.csv")
d
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
d.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
d.tail()
# Out:
#        Age  Gender    Education Level              Job Title  \
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 6699                 20.0  200000.0
# 6700                  3.0   50000.0
# 6701                  4.0   55000.0
# 6702                 14.0  140000.0
# 6703                  1.0   35000.0

# %%
# Convert categorical → numerical
df = pd.get_dummies(d, columns=['Education Level', 'Gender', 'Job Title'], drop_first=True)
df
# Out:
#        Age  Years of Experience    Salary  Education Level_Bachelor's Degree  \
# 0     32.0                  5.0   90000.0                              False
# 1     28.0                  3.0   65000.0                              False
# 2     45.0                 15.0  150000.0                              False
# 3     36.0                  7.0   60000.0                              False
# 4     52.0                 20.0  200000.0                              False
# ...    ...                  ...       ...                                ...
# 6699  49.0                 20.0  200000.0                              False
# 6700  32.0                  3.0   50000.0                              False
# 6701  30.0                  4.0   55000.0                               True
# 6702  46.0                 14.0  140000.0                              False
# 6703  26.0                  1.0   35000.0                              False
#
# ...

# %%
d.info()

# %%
d.columns[d.isna().any()]

# %%
d["Education Level"].unique()

# %%
d["Job Title"].unique()

# %%
d["Job Title"].value_counts()

# %%
d=d.drop(["Job Title"],axis=1)

# %%
d

# %%
d["Education Level"].value_counts()

# %%
d=d.drop("Education Level",axis=1)
d

# %%
d["Gender"].value_counts()

# %%
s=pd.get_dummies(d["Gender"])

# %%
d=pd.concat([d,s],axis="columns")

# %%
d

# %%
d=d.drop(["Gender"],axis="columns")
d

# %%
d.isnull().sum()

# %%
d.columns[d.isna().any()]

# %%
d[['Age', 'Years of Experience', 'Salary']]=d[['Age', 'Years of Experience', 'Salary']].fillna(d[['Age', 'Years of Experience', 'Salary']].mean())

# %%
d[['Age', 'Years of Experience', 'Salary']]

# %%
d.columns[d.isna().any()]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(d["Age"])
plt.show()

# %%
plt.scatter(d["Years of Experience"],d["Salary"])
plt.show()

# %%
d

# %%
#feature engineering
x=d[["Years of Experience"]]
y=d["Salary"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=42)

# %%
x_train

# %%
x_test

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)

# %%
y_pred=lr.predict(x_test)
y_pred

# %%
y_test

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)

# %%
lr.coef_

# %%
lr.intercept_

# %%
import numpy as np
i=np.array(2.5).reshape(-1,1)
a=lr.predict(i)
a
